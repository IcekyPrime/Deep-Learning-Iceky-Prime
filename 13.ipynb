# %% [markdown]
# # 13 计算机视觉

# %% [markdown]
# ## 13.1 图像增广

# %% [markdown]
# ## 13.2 微调

# %% [markdown]
# ## 13.3 目标检测和边界框

# %% [markdown]
# ## 13.4 锚框

# %% [markdown]
# ## 13.5 多尺度目标检测

# %% [markdown]
# ## 13.6 单发多框检测
